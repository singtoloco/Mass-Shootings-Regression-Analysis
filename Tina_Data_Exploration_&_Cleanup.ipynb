# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps
from datetime import datetime

# %%
#Load the mass shooting data
mass_2014 = pd.read_csv("DataFiles/2014.csv")
mass_2015 = pd.read_csv("DataFiles/2015.csv")
mass_2016 = pd.read_csv("DataFiles/2016.csv")
mass_2017 = pd.read_csv("DataFiles/2017.csv")

# %%
#add column for total victims from killed and injured
mass_2014['Total_Victims'] = mass_2014['# Killed'] + mass_2014['# Injured']
mass_2015['Total_Victims'] = mass_2015['# Killed'] + mass_2015['# Injured']
mass_2016['Total_Victims'] = mass_2016['# Killed'] + mass_2016['# Injured']
mass_2017['Total_Victims'] = mass_2017['# Killed'] + mass_2017['# Injured']

# %%
#totals 2014
total2014 = mass_2014['Total_Victims'].sum()
total_killed_2014 = mass_2014['# Killed'].sum()
total_injured_2014 = mass_2014['# Injured'].sum()

# %%
#totals 2015
total2015 = mass_2015['Total_Victims'].sum()
total_killed_2015 = mass_2015['# Killed'].sum()
total_injured_2015 = mass_2015['# Injured'].sum()

# %%
#totals 2016
total2016 = mass_2016['Total_Victims'].sum()
total_killed_2016 = mass_2016['# Killed'].sum()
total_injured_2016 = mass_2016['# Injured'].sum()

# %%
#totals 2017
total2017 = mass_2017['Total_Victims'].sum()
total_killed_2017 = mass_2017['# Killed'].sum()
total_injured_2017 = mass_2017['# Injured'].sum()

# %%
#combine all totals for visualizations
totals = {'Year': ['2014', '2015','2016','2017'], 'Total Injured or Killed': [total2014, total2015, total2016, total2017], 
          'Total Killed': [total_killed_2014, total_killed_2015, total_killed_2016, total_killed_2017],
          'Total Injured': [total_injured_2014, total_injured_2015, total_injured_2016, total_injured_2017]}

# %%
#Review dataframe
totals_df = pd.DataFrame(data = totals)
totals_df
# Out:
#    Year  Total Injured or Killed  Total Killed  Total Injured
# 0  2014                     1340           262           1078
# 1  2015                     1705           368           1337
# 2  2016                     1989           451           1538
# 3  2017                     2240           437           1803

# %%
#export as excel for visualization
totals_df.to_csv("OutputFiles/Tina/totals_df.csv", header=True)

# %% [markdown]
# # Total incident count

# %%
#load in coordinates for map
coordinates = pd.read_csv('DataFiles/state_names.csv')
coordinates = pd.DataFrame(data = coordinates)

# %%
#extract total shooting count and total victims per State
mass_2014_count = mass_2014.groupby(['State']).count()['Incident Date']
mass_2014_percaps = mass_2014.groupby(['State']).sum()['Total_Victims']
#convert to df
mass_2014_count = pd.DataFrame(data = mass_2014_count)
mass_2014_percaps = pd.DataFrame(data = mass_2014_percaps)
#merge with census to get full state list
mass_2014_lat = pd.merge(coordinates, mass_2014_count,on = 'State', how = 'outer')
mass_2014_states = pd.merge(mass_2014_lat, mass_2014_percaps, on = 'State', how = 'outer')
mass_2014_states = pd.DataFrame( data = mass_2014_states)

# %%
#extract total shooting count and total victims per State
mass_2015_count = mass_2015.groupby(['State']).count()['Incident Date']
mass_2015_percaps = mass_2015.groupby(['State']).sum()['Total_Victims']
#convert to df
mass_2015_count = pd.DataFrame(data = mass_2015_count)
mass_2015_percaps = pd.DataFrame(data = mass_2015_percaps)
#merge with census to get full state list
mass_2015_lat = pd.merge(coordinates, mass_2015_count,on = 'State', how = 'outer')
mass_2015_states = pd.merge(mass_2015_lat, mass_2014_percaps, on = 'State', how = 'outer')
mass_2015_states = pd.DataFrame( data = mass_2015_states)

# %%
#extract total shooting count and total victims per State
mass_2016_count = mass_2016.groupby(['State']).count()['Incident Date']
mass_2016_percaps = mass_2016.groupby(['State']).sum()['Total_Victims']
#convert to df
mass_2016_count = pd.DataFrame(data = mass_2016_count)
mass_2016_percaps = pd.DataFrame(data = mass_2016_percaps)
mass_2016_lat = pd.merge(coordinates, mass_2016_count,on = 'State', how = 'outer')
mass_2016_states = pd.merge(mass_2016_lat, mass_2016_percaps, on = 'State', how = 'outer')
mass_2016_states = pd.DataFrame( data = mass_2016_states)

# %%
#extract total shooting count and total victims per State
mass_2017_count = mass_2017.groupby(['State']).count()['Incident Date']
mass_2017_percaps = mass_2017.groupby(['State']).sum()['Total_Victims']
#convert to df
mass_2017_count = pd.DataFrame(data = mass_2017_count)
mass_2017_percaps = pd.DataFrame(data = mass_2017_percaps)
mass_2017_lat = pd.merge(coordinates, mass_2017_count,on = 'State', how = 'outer')
mass_2017_states = pd.merge(mass_2017_lat, mass_2017_percaps, on = 'State', how = 'outer')
mass_2017_states = pd.DataFrame( data = mass_2017_states)

# %%
#rename columns to tidy up the dataset
mass_2017_states = mass_2017_states.rename(columns = {'State': 'States'})
mass_2016_states = mass_2016_states.rename(columns = {'State': 'States'})
mass_2015_states = mass_2015_states.rename(columns = {'State': 'States'})
mass_2014_states = mass_2014_states.rename(columns = {'State': 'States'})

# %%
#Merge all years and rename columns
state_count_1 = pd.merge(mass_2014_states, mass_2015_states, how = 'outer', on = 'States')
state_count_2 = pd.merge(mass_2016_states,mass_2017_states, how = 'outer', on = 'States')
state_count_all = pd.merge(state_count_1, state_count_2,how = 'outer', on = 'States')

state_count_all

state_count_all.columns = ['States','Count_2014', 'Total_Victims 2014', 'Count_2015', 'Total_Victims 2015', 'Count_2016', 'Total_Victims 2016',
'Count_2017', 'Total_Victims 2017']
#fill na values with 0
state_count_all = state_count_all.fillna(0)
state_count_all.to_csv("OutputFiles/Tina/total_count_by_state.csv", header=True)

# %%
state_count_all
# Out:
#                   States  Count_2014  Total_Victims 2014  Count_2015  \
# 0                Alabama         2.0                10.0         4.0
# 1                 Alaska         1.0                 6.0         0.0
# 2                Arizona         1.0                 4.0         6.0
# 3               Arkansas         2.0                12.0         2.0
# 4             California        42.0               208.0        27.0
# 5               Colorado         2.0                 9.0         3.0
# 6            Connecticut         1.0                 5.0         2.0
# 7               Delaware         0.0                 0.0         1.0
# 8   District of Columbia         6.0                27.0         2.0
# 9                Florida        16.0                91.0        25.0
# 10               Georgia        17.0                85.0        20.0
# 11                Hawaii         0.0                 0.0         0.0
# 12                 Idaho         0.0                 0.0         0.0
# ...

# %%
#state totals
state_count_all['total_count'] = state_count_all['Count_2014'] + state_count_all['Count_2015'] + state_count_all['Count_2016'] + state_count_all['Count_2017']

#sort table for basic stats
state_count_all.sort_values(by=['Count_2017'])
# Out:
#                   States  Count_2014  Total_Victims 2014  Count_2015  \
# 51           Puerto Rico         0.0                 0.0         0.0
# 29         New Hampshire         0.0                 0.0         0.0
# 27              Nebraska         0.0                 0.0         3.0
# 50               Wyoming         0.0                 0.0         0.0
# 37                Oregon         2.0                 9.0         2.0
# 39          Rhode Island         1.0                 5.0         1.0
# 41          South Dakota         1.0                 5.0         1.0
# 45               Vermont         0.0                 0.0         1.0
# 12                 Idaho         0.0                 0.0         0.0
# 11                Hawaii         0.0                 0.0         0.0
# 34          North Dakota         0.0                 0.0         0.0
# 48         West Virginia         0.0                 0.0         0.0
# 1                 Alaska         1.0                 6.0         0.0
# ...

# %%
total_mass_shootings = state_count_all.sum()  #get total of mass shootings
#create a data frame for visualization
years = ['2014', '2015', '2016', '2017']
data = [268, 335, 382, 346]
total_mass_shootings = {'years': years, 'total_shootings' : data}
total_mass_shootings = pd.DataFrame(data = total_mass_shootings)

#export as excel for visualization
total_mass_shootings.to_csv("OutputFiles/Tina/total_mass_shootings.csv", index = False, header=True)
state_count_all.to_csv("OutputFiles/Tina/state_count_all.csv", index = False, header=True)

# %%
mass_2017_states
# Out:
#                   States  Incident Date  Total_Victims
# 0                Alabama            7.0           44.0
# 1                 Alaska            NaN            NaN
# 2                Arizona            5.0           20.0
# 3               Arkansas            3.0           37.0
# 4             California           37.0          186.0
# 5               Colorado            2.0           12.0
# 6            Connecticut            2.0            8.0
# 7               Delaware            1.0            4.0
# 8   District of Columbia            5.0           24.0
# 9                Florida           24.0          122.0
# 10               Georgia            9.0           45.0
# 11                Hawaii            NaN            NaN
# 12                 Idaho            NaN            NaN
# 13              Illinois           36.0          173.0
# 14               Indiana            7.0           33.0
# 15                  Iowa            2.0            9.0
# ...

# %% [markdown]
# # Pull US Census Data (2018 Data Not Available)

# %%
# Census & gmaps API Keys
from config import (census_key, gkey)
c = Census(census_key, year=2017)

# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"),{"for": "state:*"})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rates"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

#Add in Unemployment Rate
census_pd["Unemployment Rates"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd_2017 = census_pd[["State","Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rates", "Unemployment Count", "Unemployment Rates"]]

census_pd_2017.head()
# Out:
#   State         Name  Population  Median Age  Household Income  \
# 0    72  Puerto Rico   3468963.0        40.1           19775.0
# 1    01      Alabama   4850771.0        38.7           46472.0
# 2    02       Alaska    738565.0        33.9           76114.0
# 3    04      Arizona   6809946.0        37.2           53510.0
# 4    05     Arkansas   2977944.0        37.9           43813.0
#
#    Per Capita Income  Poverty Count  Poverty Rates  Unemployment Count  \
# 0            12081.0      1543220.0      44.486494            220597.0
# 1            25746.0       849699.0      17.516782            165391.0
# 2            35065.0        73380.0       9.935483             29548.0
# 3            27964.0      1128046.0      16.564683            225911.0
# 4            24426.0       524211.0      17.603118             85128.0
#
#    Unemployment Rates
# 0            6.359163
# 1            3.409582
# 2            4.000731
# 3            3.317368
# 4            2.858617

# %%
# Census & gmaps API Keys
c = Census(census_key, year=2016)

# Configure gmaps
gmaps.configure(api_key="AIzaSyDH3ugUF6TPqs5vaqe5M03_9DXKzT8WAe8")
# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"),{"for": "state:*"})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rates"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

#Add in Unemployment Rate
census_pd["Unemployment Rates"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd_2016 = census_pd[["State","Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rates", "Unemployment Count", "Unemployment Rates"]]

# %%
# Census & gmaps API Keys
c = Census(census_key, year=2015)

# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"),{"for": "state:*"})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rates"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

#Add in Unemployment Rate
census_pd["Unemployment Rates"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd_2015 = census_pd[["State","Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rates", "Unemployment Count", "Unemployment Rates"]]

census_pd_2015.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4830620.0        38.4           43623.0
# 1    02      Alaska    733375.0        33.4           72515.0
# 2    04     Arizona   6641928.0        36.8           50255.0
# 3    05    Arkansas   2958208.0        37.7           41371.0
# 4    06  California  38421464.0        35.8           61818.0
#
#    Per Capita Income  Poverty Count  Poverty Rates  Unemployment Count  \
# 0            24091.0       887260.0      18.367415            207097.0
# 1            33413.0        72957.0       9.948117             31285.0
# 2            25848.0      1180690.0      17.776314            275712.0
# 3            22798.0       553644.0      18.715520            104943.0
# 4            30318.0      6135142.0      15.968007           1891081.0
#
#    Unemployment Rates
# 0            4.287172
# 1            4.265894
# 2            4.151084
# 3            3.547519
# 4            4.921939

# %%
# Census & gmaps API Keys
c = Census(census_key, year=2014)

# Configure gmaps
gmaps.configure(api_key="AIzaSyDH3ugUF6TPqs5vaqe5M03_9DXKzT8WAe8")
# Run Census Search to retrieve data on all states
census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"),{"for": "state:*"})

# Convert to DataFrame
census_pd = pd.DataFrame(census_data)

# Column Reordering
census_pd = census_pd.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Add in Poverty Rate (Poverty Count / Population)
census_pd["Poverty Rates"] = 100 * \
    census_pd["Poverty Count"].astype(
        int) / census_pd["Population"].astype(int)

#Add in Unemployment Rate
census_pd["Unemployment Rates"] = 100 * \
    census_pd["Unemployment Count"].astype(
        int) / census_pd["Population"].astype(int)

# Final DataFrame
census_pd_2014 = census_pd[["State","Name", "Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rates", "Unemployment Count", "Unemployment Rates"]]

census_pd_2014.head()
# Out:
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4817678.0        38.2           43511.0
# 1    02      Alaska    728300.0        33.4           71829.0
# 2    04     Arizona   6561516.0        36.5           49928.0
# 3    05    Arkansas   2947036.0        37.6           41264.0
# 4    06  California  38066920.0        35.6           61489.0
#
#    Per Capita Income  Poverty Count  Poverty Rates  Unemployment Count  \
# 0            23936.0       889710.0      18.467610            228716.0
# 1            33129.0        71866.0       9.867637             32097.0
# 2            25537.0      1169309.0      17.820714            304067.0
# 3            22595.0       549303.0      18.639168            115090.0
# 4            29906.0      6115244.0      16.064457           2084564.0
#
#    Unemployment Rates
# 0            4.747432
# 1            4.407112
# 2            4.634097
# 3            3.905280
# 4            5.476051

# %%
#rename columns for later merging
census_pd_2014 = census_pd_2014.rename(columns = {'Name':'States'})
census_pd_2015 = census_pd_2015.rename(columns = {'Name':'States'})
census_pd_2016 = census_pd_2016.rename(columns = {'Name':'States'})
census_pd_2017 = census_pd_2017.rename(columns = {'Name':'States'})

# %%
#fill states with no mass shootings with 0 
mass_2014_states = mass_2014_states.fillna(0)
mass_2015_states = mass_2015_states.fillna(0)
mass_2016_states = mass_2016_states.fillna(0)
mass_2017_states = mass_2017_states.fillna(0)

# %%
#merge Census and mass shooting data
merged_2014 = pd.merge(mass_2014_states, census_pd_2014, on = 'States', how = 'outer')
merged_2015 = pd.merge(mass_2015_states, census_pd_2015, on = 'States', how = 'outer')
merged_2016 = pd.merge(mass_2016_states, census_pd_2016, on = 'States', how = 'outer')
merged_2017 = pd.merge(mass_2017_states, census_pd_2017, on = 'States', how = 'outer')

# %%
#load in coordinates for map
coordinates = pd.read_csv('DataFiles/state_centroids.csv')
coordinates = pd.DataFrame(data = coordinates)
#rename column for merge with full df
coordinates = coordinates.rename(columns = {'State':'States'})

#merge census & mass shooting data
merged_2014 = pd.merge(merged_2014, coordinates, on = 'States')
merged_2015 = pd.merge(merged_2015, coordinates, on = 'States')
merged_2016 = pd.merge(merged_2016, coordinates, on = 'States')
merged_2017 = pd.merge(merged_2017, coordinates, on = 'States')

#add column for per capita Mass Shooting
merged_2014['Per Capita Mass Shooting 2014'] = merged_2014['Incident Date'] / merged_2014['Population'] *1000000
merged_2015['Per Capita Mass Shooting 2015'] = merged_2015['Incident Date'] / merged_2015['Population'] *1000000
merged_2016['Per Capita Mass Shooting 2016'] = merged_2016['Incident Date'] / merged_2016['Population'] *1000000
merged_2017['Per Capita Mass Shooting 2017'] = merged_2017['Incident Date'] / merged_2017['Population'] *1000000

# %%
#rename columns to tidy up the dataset
merged_2014 = merged_2014.rename(columns = {'Incident Date': 'Mass Shooting Count'})
merged_2015 = merged_2015.rename(columns = {'Incident Date': 'Mass Shooting Count'})
merged_2016 = merged_2016.rename(columns = {'Incident Date': 'Mass Shooting Count'})
merged_2017 = merged_2017.rename(columns = {'Incident Date': 'Mass Shooting Count'})

# %%
#sort table for basic stats
merged_2017.sort_values(by=['Mass Shooting Count'])
# Out:
#                   States  Mass Shooting Count  Total_Victims State  \
# 51           Puerto Rico                  0.0            0.0    72
# 29         New Hampshire                  0.0            0.0    33
# 27              Nebraska                  0.0            0.0    31
# 50               Wyoming                  0.0            0.0    56
# 37                Oregon                  0.0            0.0    41
# 39          Rhode Island                  0.0            0.0    44
# 41          South Dakota                  0.0            0.0    46
# 45               Vermont                  0.0            0.0    50
# 12                 Idaho                  0.0            0.0    16
# 11                Hawaii                  0.0            0.0    15
# 34          North Dakota                  0.0            0.0    38
# 48         West Virginia                  0.0            0.0    54
# 1                 Alaska                  0.0            0.0    02
# ...

# %%
merged_all_1 = pd.merge(merged_2014, merged_2015, how = 'outer', on = 'States')
merged_all_2 = pd.merge(merged_2016, merged_2017, how = 'outer', on = 'States')
merged_all = pd.merge(merged_all_1, merged_all_2, how = 'outer', on = 'States')

# %%
merged_all
# Out:
#                   States  Mass Shooting Count_x_x  Total_Victims_x_x  \
# 0                Alabama                      2.0               10.0
# 1                 Alaska                      1.0                6.0
# 2                Arizona                      1.0                4.0
# 3               Arkansas                      2.0               12.0
# 4             California                     42.0              208.0
# 5               Colorado                      2.0                9.0
# 6            Connecticut                      1.0                5.0
# 7               Delaware                      0.0                0.0
# 8   District of Columbia                      6.0               27.0
# 9                Florida                     16.0               91.0
# 10               Georgia                     17.0               85.0
# 11                Hawaii                      0.0                0.0
# 12                 Idaho                      0.0                0.0
# ...

# %%
#create per Capita state df
merged_all = merged_all[['States', 'Per Capita Mass Shooting 2014', 'Per Capita Mass Shooting 2015', 'Per Capita Mass Shooting 2016','Per Capita Mass Shooting 2017']]
#set NAs to null
merged_all = merged_all.fillna(0)

# %%
#add total per capita just to filter on the visualization
merged_all['Total Per Capita'] = merged_all['Per Capita Mass Shooting 2014'] + merged_all['Per Capita Mass Shooting 2015'] + merged_all['Per Capita Mass Shooting 2016'] 
+ merged_all['Per Capita Mass Shooting 2017']
# Out:
# 0     1.443070
# 1     0.000000
# 2     0.734220
# 3     1.007406
# 4     0.949135
# 5     0.367882
# 6     0.556409
# 7     1.059623
# 8     7.436150
# 9     1.183523
# 10    0.882212
# 11    0.000000
# 12    0.000000
# 13    2.800570
# 14    1.058294
# 15    0.641416
# 16    1.377496
# 17    1.356123
# 18    3.216495
# 19    0.751790
# 20    1.334205
# 21    0.147290
# 22    0.805999
# 23    0.728501
# 24    4.353330
# 25    1.646009
# 26    0.971004
# 27    0.000000
# 28    0.692587
# 29    0.000000
# 30    1.450867
# 31    0.959312
# 32    0.656624
# 33    0.696340
# 34    0.000000
# 35    1.808824
# 36    0.256657
# 37    0.000000
# 38    1.172745
# 39    0.000000
# 40    1.430485
# 41    0.000000
# 42    2.122054
# 43    0.802345
# 44    0.334008
# 45    0.000000
# 46    1.434385
# 47    0.418412
# 48    0.000000
# 49    0.347028
# 50    0.000000
# 51    0.000000
# Name: Per Capita Mass Shooting 2017, dtype: float64

# %%
merged_all
# Out:
#                   States  Per Capita Mass Shooting 2014  \
# 0                Alabama                       0.415138
# 1                 Alaska                       1.373061
# 2                Arizona                       0.152404
# 3               Arkansas                       0.678648
# 4             California                       1.103320
# 5               Colorado                       0.384794
# 6            Connecticut                       0.278392
# 7               Delaware                       0.000000
# 8   District of Columbia                       9.467665
# 9                Florida                       0.826370
# 10               Georgia                       1.715827
# 11                Hawaii                       0.000000
# 12                 Idaho                       0.000000
# 13              Illinois                       2.020399
# 14               Indiana                       1.222791
# 15                  Iowa                       0.000000
# ...

# %%
#export as excel for visualization
merged_2014.to_csv("OutputFiles/Tina/merged_2014.csv", index = False, header=True)
merged_2015.to_csv("OutputFiles/Tina/merged_2015.csv", index = False, header=True)
merged_2016.to_csv("OutputFiles/Tina/merged_2016.csv", index = False, header=True)
merged_2017.to_csv("OutputFiles/Tina/merged_2017.csv", index = False, header=True)
merged_all.to_csv("OutputFiles/Tina/merged_all.csv", index = False, header=True)

# %% [markdown]
# # Hate Group Data

# %%
#2017
#load in hategroup activity data
hate = pd.read_csv('DataFiles/splc-hate-groups-2017.csv')
hate = pd.DataFrame(data = hate)
#rename column for merge with full df
hate = hate.rename(columns = {'State':'States'})

#create a count of hategroups by state
hate_group = hate.groupby(['States']).count()['Title']
hate_group = pd.DataFrame(data = hate_group)
hate_group = hate_group.reset_index()
hate_group_merged = pd.merge(hate_group, merged_2017, on = 'States')

#rename for tidy analysis
hate_group_merged = hate_group_merged.rename(columns = {'Title': 'Hate Group Count'})
#set hate group values to null on states which did not have a count
hate_group_merged['Hate Group Count'] = hate_group_merged['Hate Group Count'].fillna(0)

# %%
hate_group_merged
# Out:
#                   States  Hate Group Count  Mass Shooting Count  \
# 0                Alabama                23                  7.0
# 1                 Alaska                 4                  0.0
# 2                Arizona                22                  5.0
# 3               Arkansas                12                  3.0
# 4             California                75                 37.0
# 5               Colorado                21                  2.0
# 6            Connecticut                 6                  2.0
# 7               Delaware                 2                  1.0
# 8   District of Columbia                26                  5.0
# 9                Florida                66                 24.0
# 10               Georgia                40                  9.0
# 11                Hawaii                 1                  0.0
# 12                 Idaho                12                  0.0
# 13              Illinois                35                 36.0
# ...

# %%
#create df without black nationalist groups
hate2 = hate.loc[hate['Ideology'] != 'Black Nationalist', :]
#create a count of hategroups by state
hate_groupb = hate2.groupby(['States']).count()['Title']
hate_group2 = pd.DataFrame(data = hate_groupb)
hate_group2 = hate_group2.reset_index()
hate_group_merged2 = pd.merge(merged_2017, hate_group2, on = 'States')

#rename for tidy analysis
hate_group_merged2 = hate_group_merged2.rename(columns = {'Title': 'Hate Group Count'})

#set hate group values to null on states which did not have a count
hate_group_merged2['Hate Group Count'] = hate_group_merged2['Hate Group Count'].fillna(0)

# %%
#2016
#load in hategroup activity data
hate2016 = pd.read_csv('DataFiles/splc-hate-groups-2016.csv')
hate2016 = pd.DataFrame(data = hate2016)
#rename column for merge with full df
hate2016 = hate2016.rename(columns = {'State':'States'})

#create a count of hategroups by state
hate_group_2016 = hate2016.groupby(['States']).count()['Title']
hate_group_2016 = pd.DataFrame(data = hate_group_2016)
hate_group_2016 = hate_group_2016.reset_index()
hate_group_merged_2016 = pd.merge(merged_2016, hate_group_2016, on = 'States', how = 'outer')

#remove Puerto Rico
hate_group_merged_2016 = hate_group_merged_2016.drop(51, axis = 0)

#rename for tidy analysis
hate_group_merged_2016 = hate_group_merged_2016.rename(columns = {'Title': 'Hate Group Count'})
#set hate group values to null on states which did not have a count
hate_group_merged_2016['Hate Group Count'] = hate_group_merged_2016['Hate Group Count'].fillna(0)

# %%
#2015
#load in hategroup activity data
hate2015 = pd.read_csv('DataFiles/splc-hate-groups-2015.csv')
hate2015 = pd.DataFrame(data = hate2015)
#rename column for merge with full df
hate2015 = hate2015.rename(columns = {'State':'States'})

#create a count of hategroups by state
hate_group_2015 = hate2015.groupby(['States']).count()['Title']
hate_group_2015 = pd.DataFrame(data = hate_group_2015)
hate_group_2015 = hate_group_2015.reset_index()
hate_group_merged_2015 = pd.merge(merged_2015, hate_group_2015, on = 'States', how = 'outer')

#remove Puerto Rico
hate_group_merged_2015 = hate_group_merged_2015.drop(51, axis = 0)

#rename for tidy analysis
hate_group_merged_2015 = hate_group_merged_2015.rename(columns = {'Title': 'Hate Group Count'})
hate_group_merged_2015['Hate Group Count'] = hate_group_merged_2015['Hate Group Count'].fillna(0)

# %%
#2014
#load in hategroup activity data
hate2014 = pd.read_csv('DataFiles/splc-hate-groups-2014.csv')
hate2014 = pd.DataFrame(data = hate2014)
#rename column for merge with full df
hate2014 = hate2014.rename(columns = {'State':'States'})

#create a count of hategroups by state
hate_group_2014 = hate2014.groupby(['States']).count()['Title']
hate_group_2014 = pd.DataFrame(data = hate_group_2014)
hate_group_2014 = hate_group_2014.reset_index()

#add 0 for Alaska, no hategroups recorded which was lost by the group by
hate_group_2014 = hate_group_2014.append({'States' : 'Alaska' , 'Title': 0}, ignore_index=True )
hate_group_merged_2014 = pd.merge(merged_2014, hate_group_2014, on = 'States', how = 'outer')

#remove Puerto Rico
hate_group_merged_2014 = hate_group_merged_2014.drop(51, axis = 0)

#rename for tidy analysis
hate_group_merged_2014 = hate_group_merged_2014.rename(columns = {'Title': 'Hate Group Count'})
hate_group_merged_2014['Hate Group Count'] = hate_group_merged_2014['Hate Group Count'].fillna(0)
hate_group_merged_2015['Hate Group Count'] = hate_group_merged_2015['Hate Group Count'].fillna(0)

# %%
hate_group_merged_2014
# Out:
#                   States  Mass Shooting Count  Total_Victims State  \
# 0                Alabama                  2.0           10.0    01
# 1                 Alaska                  1.0            6.0    02
# 2                Arizona                  1.0            4.0    04
# 3               Arkansas                  2.0           12.0    05
# 4             California                 42.0          208.0    06
# 5               Colorado                  2.0            9.0    08
# 6            Connecticut                  1.0            5.0    09
# 7               Delaware                  0.0            0.0    10
# 8   District of Columbia                  6.0           27.0    11
# 9                Florida                 16.0           91.0    12
# 10               Georgia                 17.0           85.0    13
# 11                Hawaii                  0.0            0.0    15
# 12                 Idaho                  0.0            0.0    16
# ...

# %%
#new column for hate groups per capita
hate_group_merged['Per Capita Hate Group'] = hate_group_merged['Hate Group Count'] / hate_group_merged['Population'] * 100000
hate_group_merged2['Per Capita Hate Group'] = hate_group_merged2['Hate Group Count'] / hate_group_merged2['Population'] * 100000
hate_group_merged_2016['Per Capita Hate Group'] = hate_group_merged_2016['Hate Group Count'] / hate_group_merged_2016['Population'] * 100000
hate_group_merged_2015['Per Capita Hate Group'] = hate_group_merged_2015['Hate Group Count'] / hate_group_merged_2015['Population'] * 100000
hate_group_merged_2014['Per Capita Hate Group'] = hate_group_merged_2014['Hate Group Count'] / hate_group_merged_2014['Population'] * 100000

# %%
#export as excel for visualization
hate_group_merged.to_csv("OutputFiles/Tina/hate_group_merged.csv", index = False, header=True)
hate_group_merged2.to_csv("OutputFiles/Tina/hate_group_merged2.csv", index = False, header=True)
hate_group_merged_2016.to_csv("OutputFiles/Tina/hate_group_merged_2016.csv", index = False, header=True)
hate_group_merged_2015.to_csv("OutputFiles/Tina/hate_group_merged_2015.csv", index = False, header=True)
hate_group_merged_2014.to_csv("OutputFiles/Tina/hate_group_merged_2014.csv", index = False, header=True)

# %% [markdown]
# # Add Gun Score

# %%
#load data
gunscores_2014 = pd.read_csv('DataFiles/gunlaw_2014_grade_number.csv')
gunscores_2014 = pd.DataFrame(data = gunscores_2014)
gunscores_2015 = pd.read_csv('DataFiles/gunlaw_2015_grade_number.csv')
gunscores_2015 = pd.DataFrame(data = gunscores_2015)
gunscores_2016 = pd.read_csv('DataFiles/gunlaw_2016_grade_number.csv')
gunscores_2016 = pd.DataFrame(data = gunscores_2016)
gunscores_2017 = pd.read_csv('DataFiles/gunlaw_2017_grade_number.csv')
gunscores_2017 = pd.DataFrame(data = gunscores_2017)

# %%
#remove uneeded columns & rename for merge
gunscores_2014 = gunscores_2014.drop(['Unnamed: 0', 'GUN LAW STRENGTH (RANKED)', '2014 GRADE'], axis = 1)
gunscores_2014 = gunscores_2014.rename(columns = {'STATE': 'States'})
gunscores_2015 = gunscores_2015.drop(['Unnamed: 0', 'GUN LAW STRENGTH (RANKED)', '2015 GRADE'], axis = 1)
gunscores_2015 = gunscores_2015.rename(columns = {'STATE': 'States'})
gunscores_2016 = gunscores_2016.drop(['Unnamed: 0', 'GUN LAW STRENGTH (RANKED)', '2016 GRADE'], axis = 1)
gunscores_2016 = gunscores_2016.rename(columns = {'STATE': 'States'})
gunscores_2017 = gunscores_2017.drop(['Unnamed: 0', 'GUN LAW STRENGTH (RANKED)', '2017 GRADE'], axis = 1)
gunscores_2017 = gunscores_2017.rename(columns = {'STATE': 'States'})

# %%
#district of columbia does not have a score - we will give it a midrange score
gunscores_2014 = gunscores_2014.append({'States' : 'District of Columbia' , 'GRADE number': 3.0} , ignore_index=True)
gunscores_2015 = gunscores_2015.append({'States' : 'District of Columbia' , 'GRADE number': 3.0} , ignore_index=True)
gunscores_2016 = gunscores_2016.append({'States' : 'District of Columbia' , 'GRADE number': 3.0} , ignore_index=True)
gunscores_2017 = gunscores_2017.append({'States' : 'District of Columbia' , 'GRADE number': 3.0} , ignore_index=True)

# %%
#merge with hate group data
hate_and_gunscore_2017 = pd.merge(hate_group_merged, gunscores_2017, how = 'outer', on = 'States')
hate_and_gunscore_2016 = pd.merge(hate_group_merged_2016, gunscores_2016, how = 'outer', on = 'States')
hate_and_gunscore_2015 = pd.merge(hate_group_merged_2015, gunscores_2015, how = 'outer', on = 'States')
hate_and_gunscore_2014 = pd.merge(hate_group_merged_2014, gunscores_2014, how = 'outer', on = 'States')

# %%
hate_and_gunscore_2017
# Out:
#                   States  Hate Group Count  Mass Shooting Count  \
# 0                Alabama                23                  7.0
# 1                 Alaska                 4                  0.0
# 2                Arizona                22                  5.0
# 3               Arkansas                12                  3.0
# 4             California                75                 37.0
# 5               Colorado                21                  2.0
# 6            Connecticut                 6                  2.0
# 7               Delaware                 2                  1.0
# 8   District of Columbia                26                  5.0
# 9                Florida                66                 24.0
# 10               Georgia                40                  9.0
# 11                Hawaii                 1                  0.0
# 12                 Idaho                12                  0.0
# 13              Illinois                35                 36.0
# ...

# %%
#double check that all items are intact from original dataset on all new datasets with 51 States (including District of Columbia)
len(hate_and_gunscore_2014)
len(hate_group_merged_2014)
# Out:
# 51

# %%
#renamecolumns so they match for the merge
hate_and_gunscore_2017 = hate_and_gunscore_2017.rename(columns = {'Per Capita Mass Shooting 2017': 'Per Capita Mass Shooting'})
hate_and_gunscore_2016 = hate_and_gunscore_2016.rename(columns = {'Per Capita Mass Shooting 2016': 'Per Capita Mass Shooting'})
hate_and_gunscore_2015 = hate_and_gunscore_2015.rename(columns = {'Per Capita Mass Shooting 2015': 'Per Capita Mass Shooting'})
hate_and_gunscore_2014 = hate_and_gunscore_2014.rename(columns = {'Per Capita Mass Shooting 2014': 'Per Capita Mass Shooting'})

# %%
#export as excel for visualization
hate_and_gunscore_2017.to_csv("OutputFiles/Tina/hate_and_gunscore_2017.csv", index = False, header=True)
hate_and_gunscore_2016.to_csv("OutputFiles/Tina/hate_and_gunscore_2016.csv", index = False, header=True)
hate_and_gunscore_2015.to_csv("OutputFiles/Tina/hate_and_gunscore_2015.csv", index = False, header=True)
hate_and_gunscore_2014.to_csv("OutputFiles/Tina/hate_and_gunscore_2014.csv", index = False, header=True)

# %%
hate_and_gunscore_2014.columns
# Out:
# Index(['States', 'Mass Shooting Count', 'Total_Victims', 'State', 'Population',
#        'Median Age', 'Household Income', 'Per Capita Income', 'Poverty Count',
#        'Poverty Rates', 'Unemployment Count', 'Unemployment Rates', 'Latitude',
#        'Longitude', 'Per Capita Mass Shooting', 'Hate Group Count',
#        'Per Capita Hate Group', 'GRADE number'],
#       dtype='object')

# %% [markdown]
# # Guncheck & US Election Data

# %%
#load data
gunchecks__election_2014 = pd.read_csv('DataFiles/GunChecks_Election14.csv')
gunchecks__election_2014 = pd.DataFrame(data = gunchecks__election_2014)
gunchecks__election_2015 = pd.read_csv('DataFiles/GunChecks_Election15.csv')
gunchecks__election_2015 = pd.DataFrame(data = gunchecks__election_2015)
gunchecks__election_2016 = pd.read_csv('DataFiles/GunChecks_Election16.csv')
gunchecks__election_2016 = pd.DataFrame(data = gunchecks__election_2016)
gunchecks__election_2017 = pd.read_csv('DataFiles/GunChecks_Election17.csv')
gunchecks__election_2017 = pd.DataFrame(data = gunchecks__election_2017)

# %%
gunchecks__election_2014.head()
# Out:
#    Unnamed: 0      States  Gun Check Totals Result2014
# 0           0     Alabama            621305          R
# 1           1      Alaska             87623          R
# 2           2     Arizona            310672          R
# 3           3    Arkansas            234282          R
# 4           4  California           1474616          B

# %%
#remove uneeded columns & rename for merge
gunchecks__election_2014 = gunchecks__election_2014.drop(['Unnamed: 0'], axis = 1)
gunchecks__election_2015 = gunchecks__election_2015.drop(['Unnamed: 0'], axis = 1)
gunchecks__election_2016 = gunchecks__election_2016.drop(['Unnamed: 0'], axis = 1)
gunchecks__election_2017 = gunchecks__election_2017.drop(['Unnamed: 0'], axis = 1)

# %%
#renamecolumns so they match for the merge
gunchecks__election_2014 = gunchecks__election_2014.rename(columns = {'Result2014': 'Election_Result'})
gunchecks__election_2015 = gunchecks__election_2015.rename(columns = {'Result2015': 'Election_Result'})
gunchecks__election_2016 = gunchecks__election_2016.rename(columns = {'Result2016': 'Election_Result'})
gunchecks__election_2017 = gunchecks__election_2017.rename(columns = {'Result2014': 'Election_Result'})

# %%
#merge with hate group & gun score data
combined_2014 = pd.merge(hate_and_gunscore_2014, gunchecks__election_2014, how = 'outer', on = 'States')
combined_2015 = pd.merge(hate_and_gunscore_2015, gunchecks__election_2015, how = 'outer', on = 'States')
combined_2016 = pd.merge(hate_and_gunscore_2016, gunchecks__election_2014, how = 'outer', on = 'States')
combined_2017 = pd.merge(hate_and_gunscore_2017, gunchecks__election_2014, how = 'outer', on = 'States')

# %%
#double check that all items are intact from original dataset
len(combined_2014)
len(hate_and_gunscore_2014)
# Out:
# 51

# %%
#check for any nans 
combined_2014.isnull().values.any()
combined_2015.isnull().values.any()
combined_2016.isnull().values.any()
combined_2017.isnull().values.any()
# Out:
# False

# %%
#export as excel for visualization
combined_2014.to_csv("OutputFiles/Tina/combined_2014.csv", index = False, header=True)
combined_2015.to_csv("OutputFiles/Tina/combined_2015.csv", index = False, header=True)
combined_2016.to_csv("OutputFiles/Tina/combined_2016.csv", index = False, header=True)
combined_2017.to_csv("OutputFiles/Tina/combined_2017.csv", index = False, header=True)

# %%
combined_2017
# Out:
#                   States  Hate Group Count  Mass Shooting Count  \
# 0                Alabama                23                  7.0
# 1                 Alaska                 4                  0.0
# 2                Arizona                22                  5.0
# 3               Arkansas                12                  3.0
# 4             California                75                 37.0
# 5               Colorado                21                  2.0
# 6            Connecticut                 6                  2.0
# 7               Delaware                 2                  1.0
# 8   District of Columbia                26                  5.0
# 9                Florida                66                 24.0
# 10               Georgia                40                  9.0
# 11                Hawaii                 1                  0.0
# 12                 Idaho                12                  0.0
# 13              Illinois                35                 36.0
# ...

# %% [markdown]
# # Linear Regression Prep

# %%
#df frame list
frames = [combined_2017, combined_2016,combined_2015, combined_2014]
#combine dfs
linear_dataset = pd.concat(frames)
linear_dataset.head()
# Out:
# C:\Users\chris\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
#   Election_Result  GRADE number  Gun Check Totals  Hate Group Count  \
# 0               R           5.5            621305              23.0
# 1               R           5.5             87623               4.0
# 2               R           5.5            310672              22.0
# 3               R           5.5            234282              12.0
# 4               B           0.0           1474616              75.0
#
#    Household Income  Latitude  Longitude  Mass Shooting Count  Median Age  \
# 0           46472.0   32.7794   -86.8287                  7.0        38.7
# ...

# %%
len(linear_dataset)#double check length 2014, looks good
# Out:
# 204

# %%
linear_dataset.columns
# Out:
# Index(['Election_Result', 'GRADE number', 'Gun Check Totals',
#        'Hate Group Count', 'Household Income', 'Latitude', 'Longitude',
#        'Mass Shooting Count', 'Median Age', 'Per Capita Hate Group',
#        'Per Capita Income', 'Per Capita Mass Shooting', 'Population',
#        'Poverty Count', 'Poverty Rates', 'State', 'States', 'Total_Victims',
#        'Unemployment Count', 'Unemployment Rates'],
#       dtype='object')

# %%
#rearrange columns
linear_dataset = linear_dataset[['States', 'Total_Victims',
       'Unemployment Count', 'Unemployment Rates', 'GRADE number', 'Gun Check Totals',
       'Hate Group Count', 'Household Income', 'Latitude', 'Longitude',
       'Mass Shooting Count', 'Median Age', 'Per Capita Hate Group',
       'Per Capita Income', 'Per Capita Mass Shooting', 'Population',
       'Poverty Count', 'Poverty Rates','Election_Result' ]]

# %%
#create dummy variables for Election result to include in regression
linear_with_dummies = pd.get_dummies(linear_dataset, columns = ['Election_Result'] )

# %%
len(linear_with_dummies)
# Out:
# 204

# %%
#export as excel for visualization
linear_with_dummies.to_csv("OutputFiles/Tina/linear_with_dummies.csv", index = False, header=True)
